# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from testing.gain_patterns.main import get_tone_ladder_recording

freqs = range(15000, 50000, 1000)
tone_length = 1e4

signal = get_tone_ladder_recording(freqs, tone_length)
signal = signal.flatten().astype(np.int32)

signal
# Out:
#    ___  ____  ___  _____  __
#   / _ \/ __ \/ _ )/  _/ |/ /
#  / , _/ /_/ / _  |/ //    /
# /_/|_|\____/____/___/_/|_/
# The wearable echolocator
#
# Notice: not configured as a Robin headset. Export ROBIN_IS_DEVICE=1 to make that happen.
# Warning: ROBIN_DEVICE_ID not set. Using robin-protoype instead.
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# Warning: discarded sample
# array([-240, -236, -237, ..., -236, -237, -237], dtype=int32)

# %%
original_dtype = signal.dtype


# Normalization factor based on the maximum value of the input dtype
dtype_max = np.iinfo(original_dtype).max if np.issubdtype(original_dtype, np.integer) else 1.0

# Convert to float32 and normalize
normalized_signal = signal.astype(np.float32) / dtype_max

plt.plot(normalized_signal)

# %%
threshold_db = -30
filter_window_length = 2000

# Square each element to get signal power timeseries
power_signal = np.square(normalized_signal)

# Compute threshold power
threshold_power = np.max(power_signal) * 10 ** (threshold_db / 10)

# Apply low-pass filtering on the power signal
window = np.ones(filter_window_length) / filter_window_length
filtered_power_signal = np.convolve(power_signal, window, mode='same')

plt.plot(filtered_power_signal)

# %%
# Map each element to 0 or 1 based on threshold
thresholded_signal = (filtered_power_signal > threshold_power).astype(int)

plt.plot(thresholded_signal)

# %%
non_silent_segments = []
start = None
for i, value in enumerate(thresholded_signal):
    if value == 1 and start is None:
        start = i
    elif value == 0 and start is not None:
        segment = normalized_signal[start:i] * dtype_max
        print("segment", start, i, len(thresholded_signal))
        non_silent_segments.append(segment.astype(original_dtype))
        start = None
if start is not None:
    segment = normalized_signal[start:] * dtype_max
    non_silent_segments.append(segment.astype(original_dtype))

non_silent_segments
# Out:
# segment 40887 44861 711228
# segment 60962 64949 711228
# segment 80980 84960 711228
# segment 101000 104986 711228
# segment 121014 125011 711228
# segment 141046 145034 711228
# segment 161055 165053 711228
# segment 181072 185065 711228
# segment 200885 204887 711228
# segment 220920 224982 711228
# segment 240950 244960 711228
# segment 260964 264951 711228
# segment 280976 284958 711228
# segment 300990 304969 711228
# segment 321021 324994 711228
# segment 341048 344982 711228
# segment 361047 364978 711228
# segment 381073 385025 711228
# segment 401102 405034 711228
# segment 421115 425044 711228
# segment 441193 445078 711228
# segment 461288 465145 711228
# segment 481358 485223 711228
# segment 501381 505255 711228
# segment 521396 525143 711228
# segment 541423 545179 711228
# segment 561482 565257 711228
# segment 581530 585378 711228
# segment 601566 605388 711228
# segment 621673 625340 711228
# segment 642113 644853 711228
# segment 662384 664680 711228
# segment 682772 684124 711228
# segment 684126 684127 711228
# segment 684130 684131 711228
# [array([-236, -240, -237, ..., -241, -220, -204], dtype=int32),
#  array([-237, -236, -237, ..., -265, -236, -208], dtype=int32),
#  array([-244, -241, -237, ..., -233, -241, -241], dtype=int32),
#  array([-237, -236, -237, ..., -220, -205, -200], dtype=int32),
#  array([-237, -240, -240, ..., -281, -229, -180], dtype=int32),
#  array([-237, -237, -241, ..., -224, -197, -189], dtype=int32),
#  array([-237, -237, -240, ..., -293, -261, -225], dtype=int32),
#  array([-236, -237, -236, ..., -300, -264, -224], dtype=int32),
#  array([-240, -237, -233, ..., -220, -184, -180], dtype=int32),
#  array([-237, -241, -237, ..., -297, -320, -316], dtype=int32),
#  array([-237, -240, -237, ..., -293, -288, -265], dtype=int32),
#  array([-240, -236, -237, ..., -232, -221, -217], dtype=int32),
#  array([-240, -236, -237, ..., -224, -225, -233], dtype=int32),
#  array([-237, -237, -236, ..., -237, -249, -249], dtype=int32),
#  array([-237, -236, -237, ..., -248, -269, -260], dtype=int32),
#  array([-237, -237, -237, ..., -240, -240, -236], dtype=int32),
#  array([-236, -237, -237, ..., -232, -233, -233], dtype=int32),
#  array([-240, -237, -237, ..., -252, -236, -228], dtype=int32),
#  array([-237, -237, -240, ..., -225, -217, -229], dtype=int32),
#  array([-241, -237, -237, ..., -241, -220, -217], dtype=int32),
#  array([-237, -237, -237, ..., -248, -232, -220], dtype=int32),
#  array([-237, -240, -237, ..., -233, -225, -229], dtype=int32),
#  array([-237, -236, -237, ..., -237, -237, -237], dtype=int32),
#  array([-236, -237, -236, ..., -241, -245, -244], dtype=int32),
#  array([-240, -240, -240, ..., -237, -244, -237], dtype=int32),
#  array([-237, -237, -237, ..., -228, -240, -248], dtype=int32),
#  array([-236, -237, -237, ..., -228, -245, -257], dtype=int32),
#  array([-236, -236, -237, ..., -237, -229, -225], dtype=int32),
#  array([-237, -237, -236, ..., -236, -220, -228], dtype=int32),
#  array([-237, -237, -237, ..., -217, -232, -240], dtype=int32),
#  array([-236, -237, -240, ..., -241, -220, -229], dtype=int32),
#  array([-237, -237, -241, ..., -241, -337, -256], dtype=int32),
#  array([-104, -368, -493, ..., -368, -484, -153], dtype=int32),
#  array([-525], dtype=int32),
#  array([-313], dtype=int32)]

# %%
segs_and_idxs = []
for idx, segment in enumerate(non_silent_segments):
    segs_and_idxs.append((segment, idx))
segs_by_length = list(sorted(segs_and_idxs, key=lambda pair: -len(pair[0])))
longest_segs_unsorted = segs_by_length[0:len(freqs)]
tone_segments = [pair[0] for pair in list(sorted(longest_segs_unsorted, key=lambda pair: pair[1]))]

# %%
from robin.util import bandpass

powers = {}
for idx, freq in enumerate(freqs):
    segment = tone_segments[idx].astype(np.int32)
    power = np.sum(segment ** 2) / len(segment)
    powers[freq] = power

# %%
plt.plot(signal)

# %%
plt.yscale("log")
plt.plot(powers.keys(), powers.values())
